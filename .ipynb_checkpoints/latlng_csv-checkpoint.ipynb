# %%
import plotly.plotly as py
import plotly.graph_objs as go
import pandas as pd
import gmaps
import requests

# %%
gkey = "AIzaSyBPqTW_jbfLM7KUAKC9If7WPfdH-swvow4"

target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
    'address={0}&key={1}').format('Kansas City', gkey)

py.sign_in('britalvr','MtxMIzvWQN4A9fPpY7bA')

# %%
citystate_df = pd.read_csv("Rest_Scores_data.csv")

# Run a request to endpoint and convert result to json
geo_data = requests.get(target_url).json()
cities_df = pd.DataFrame(citystate_df['business_address'])
# Print the json
# geo_data['results'][0]['geometry']['location']['lat']
# geo_data['results'][0]['geometry']['location']['lng']

cities_df
# Out:
#                          business_address
# 0                         1408 Clement St
# 1                             1 Kearny St
# 2                         4615 Mission St
# 3                            552 Jones St
# 4                             691 14th St
# 5                           747 Howard St
# 6                           3161 24th St.
# 7                201 Harrison St Unit C-2
# 8                           799 Bryant St
# 9                            3338 24th St
# 10                        2351 Mission St
# 11                         852 Clement St
# 12                          865 Market St
# 13                        50 Post St #65A
# 14                          375 Taylor St
# 15                595 Market St Suite 160
# 16                        59 Columbus Ave
# 17     24 Willie Mays Pl View Section 302
# 18                           1356 Polk St
# 19                           Off The Grid
# 20                           5273 03rd St
# ...

# %%
lat = []
lng = []


for x in cities_df[0]:
    try:
        target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
        'address={0}&key={1}').format(f'{x}', gkey)
        geo_data = requests.get(target_url).json()
        lat.append(geo_data['results'][0]['geometry']['location']['lat'])
        lng.append(geo_data['results'][0]['geometry']['location']['lng'])
    except:
        IndexError
        lat.append('Null')
        lng.append('Null')
        
        
cities_df['Lat'] = lat
cities_df['Lng'] = lng
merged_df = cities_df.merge(citystate_df, left_on= 0, right_on='business_address')

merged_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-57b8355355f0> in <module>
#       3
#       4
# ...
